# %% [markdown]
# ### Import Libraries

# %%
import cv2 as cv
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Load Image

# %%
img = cv.imread('../week - 01/KTP.jpeg')
plt.imshow(img)
