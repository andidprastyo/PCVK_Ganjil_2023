# %% [markdown]
# <a href="https://colab.research.google.com/github/andidprastyo/PCVK_Ganjil_2023/blob/main/week%20-%2002/week02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Import Library

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from google.colab import drive
drive.mount('/content/drive')
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Load image

# %%
img = cv.imread('/content/drive/MyDrive/Images/Images/kitten01.jpg')
plt.imshow(img)

# %%
# Convert BGR to RGB
img2 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img2)

# %%
### Grayscaling
grayscale_img = cv.imread('/content/drive/MyDrive/Images/Images/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(grayscale_img)

# %%
plt.imshow(grayscale_img, cmap='gray')

# %%
plt.imshow(grayscale_img, cmap='magma')

# %%
# Resize
img3 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB),(512, 1024))
plt.imshow(img3)

# %%
# flip image
img4 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)
# cv.imwrite('/content/drive/MyDrive/Images/Images/mandrill2.tiff', img4) # save image

fig=plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img4)

# %% [markdown]
# ### Shapes

# %%
black = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black)

# %%
cv.rectangle(black,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black)

# %%
cv.rectangle(black,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black)

# %%
cv.circle(black,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black)

# %%
cv.line(black,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black, text="Hello", org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2, lineType=cv.LINE_AA)
plt.imshow(black)

# %%
black_2 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_2)

# %%
vertices = np.array([[100,300], [200,200], [400, 300], [200, 400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_2, [pts], isClosed=True, color=(255,0,0), thickness=5)
plt.imshow(black_2)

# %% [markdown]
# # Pertanyaan
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16
# dan int32?
# 3. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode
# berikut
#
# ```python
# from google.colab.patches import cv2_imshow
# from skimage import io
# ```
#
# 4. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3

# %% [markdown]
# # Jawaban
# 1. Matplotlib akan menampilkan ukuran x dan y dari gambar
# 2. Perbedaan tipe int16 akan memiliki nilai minimum yang lebih rendah dibanding int32 dan membuat jangkauan warna int32 lebih baik, namun bila dilihat secara kasat mata tidak ada perbedaan signifikan.
# 3. ``` cv2_imshow ``` digunakan untuk menampilkan gambar pada output cell
# 4. ```from skimage import io``` digunakan untuk menampilkan gambar pada output cell
